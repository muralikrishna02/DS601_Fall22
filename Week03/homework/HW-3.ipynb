# %% [markdown]
# # Data 601 HW-3

# %% [markdown]
# # Set-up

# %% [markdown]
# Import the `Pandas` library with the alias `pd`. Note that this question doesn't have any point value but if you cannot successfully complete this question you will automatically get zero from this assignment.

# %%
## your answer is here

# %% [markdown]
# # Question

# %% [markdown]
# From the dictionary `data` create a dataframe named `df` and set the index as the `Name` column. The result should look like:
#
# ![Screen Shot 2021-02-24 at 3.46.20 PM.png](data:image/png;base64,...)

# %%
## don't change this cell
data = {
    "Name": ["Jim", "Dwight", "Angela", "Tobi"],
    "Age": [26, 28, 27, 32],
    "Department": ["Sales", "Sales", "Accounting", "Human Resources"]
}

# %%
## your answer is here

# %% [markdown]
# # Question

# %%
## don't change this cell
credit = pd.read_csv('https://raw.githubusercontent.com/nguyen-toan/ISLR/master/dataset/Credit.csv')

# %% [markdown]
# Above we created `credit` dataframe. In this dataframe there is a column called `Unnamed: 0`. Drop this column so that `credit` dataframe doesn't have this column anymore.

# %%
## your code is here.

# %% [markdown]
# # Question

# %% [markdown]
# What is the maximum income in the  `credit` dataframe? And what is the `Limit` of this this customer?

# %%
## your code is here

# %% [markdown]
# # Question

# %%
## Don't change this cell
## make sure that you run this cell

worldcup = pd.read_csv('https://raw.githubusercontent.com/msaricaumbc/DS_data/master/world_cup.csv')

# %% [markdown]
# In the cell above, we created `worldcup` dataset. This data contains games played during FIFA World Cup Tournaments.

# %% [markdown]
# A - Show the first 7 rows of the dataframe `worldcup`.

# %%
## your answer is here.

# %% [markdown]
# B - Show the last 7 rows of the dataframe `worldcup`.

# %%
## your answer is here.

# %% [markdown]
# # Question

# %% [markdown]
# What is the city in the 21th row? (Hint: Python starts counting from 0)

# %%
## your answer is here

# %% [markdown]
# # Question

# %% [markdown]
# Change the columns names `Home Team Goals` to `HomeTeamGoals` and `Home Team Name` to `HomeTeamName`. Make sure that the changes take place in the original dataframe `worldcup`. The columns of `worldcup` dataframe should look like this after you solve the problem:

# %% [markdown]
# ![Screen Shot 2021-02-24 at 4.30.58 PM.png](data:image/png;base64,...)

# %%
## your code is here

# %% [markdown]
# # Question

# %% [markdown]
# Find out if there is any columns with `missing` values.
#
# __Note:__ Here we are using the notion `missing values` in the sense of values with 'Nan' or 'NA'

# %%
## your answer is here

# %% [markdown]
# # Question

# %% [markdown]
# A - Drop __the columns__ that contains missing values. __Don't change the original dataframe__

# %%
## your answer is here.

# %% [markdown]
# B - Drop __the rows__ that contains missing values. __Don't change the original dataframe!__

# %%
## your answer is here

# %% [markdown]
# # Question

# %% [markdown]
# As we noticed in the previous question we have some missing values in the `worldcup` dataframe. Fill out these missing values in `Attendance` column with the average attance through-out the tournament history.

# %%
## your answer is here

# %% [markdown]
# # Question

# %% [markdown]
# How many different values are there in the `Year` column?

# %%
## your answer here

# %% [markdown]
# # Part-III Submission
#
# Make sure to save this file under Week03 folder in your repository
# Commit & Push
